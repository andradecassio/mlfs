# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import pandas as pd
import warnings
import os
import random

from sklearn import preprocessing
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import LeaveOneGroupOut
from sklearn import metrics

from imblearn.pipeline import Pipeline as ImbPipeline
from itertools import product
import time

import pickle

# %% [markdown]
# ## Importing data

# %%
# Moving to project directory
os.chdir('..')

# %%
data_set = pd.read_pickle("data/processed/data_set.pkl")
data_set
# Out:
#                baseClassifier  datasetName              attributeName  \
# 0    simpleLogisticRegression         iris                petallength
# 1    simpleLogisticRegression         iris                 petalwidth
# 2    simpleLogisticRegression         iris                sepallength
# 3    simpleLogisticRegression         iris                 sepalwidth
# 4    simpleLogisticRegression  labor_part1  wage-increase-second-year
# ..                        ...          ...                        ...
# 488  simpleLogisticRegression          zoo                    aquatic
# 489  simpleLogisticRegression          zoo                    catsize
# 490  simpleLogisticRegression          zoo                   venomous
# 491  simpleLogisticRegression          zoo                   predator
# 492  simpleLogisticRegression          zoo                   domestic
#
#      dsMatrixCorrelSD  dsEigenvaluePropIntercept  \
# 0            0.666645                   0.493463
# 1            0.666645                   0.493463
# 2            0.666645                   0.493463
# 3            0.666645                   0.493463
# 4            0.406496                   0.216496
# ..                ...                        ...
# 488          0.381562                   0.156774
# 489          0.381562                   0.156774
# 490          0.381562                   0.156774
# 491          0.381562                   0.156774
# 492          0.381562                   0.156774
#
#      dsEigenvalueCumulativeIntercept  dsChiSquaredMax  \
# 0                           0.719181       268.419048
# 1                           0.719181       268.419048
# 2                           0.719181       268.419048
# 3                           0.719181       268.419048
# 4                           0.398940        15.064286
# ..                               ...              ...
# 488                         0.517723       208.165859
# 489                         0.517723       208.165859
# 490                         0.517723       208.165859
# 491                         0.517723       208.165859
# 492                         0.517723       208.165859
#
#      attChiSquaredNormalized  attClassifierLogisticNormalized  \
# 0                   1.000000                         0.988836
# 1                   0.994371                         1.000000
# 2                   0.470954                         0.657097
# 3                   0.263171                         0.357257
# 4                   1.000000                         1.000000
# ..                       ...                              ...
# 488                 0.222956                         0.350015
# 489                 0.178550                         0.249975
# 490                 0.091768                         0.000000
# 491                 0.058555                         0.000000
# 492                 0.023116                         0.000000
#
#      attCorrelationNormalized  attReliefFNormalized  \
# 0                    1.000000              0.954787
# 1                    0.962602              1.000000
# 2                    0.777236              0.372340
# 3                    0.645528              0.324468
# 4                    0.878689              0.956530
# ..                        ...                   ...
# 488                  0.463506              0.363265
# 489                  0.555631              0.366118
# 490                  0.297375              0.046668
# 491                  0.154953              0.105274
# 492                  0.170703             -0.003189
#
#      attSymmetricalUncertNormalized  dsLOGnInstances  dsLnNumClasses  \
# 0                          0.925373         2.176091        1.098612
# 1                          1.000000         2.176091        1.098612
# 2                          0.469575         2.176091        1.098612
# 3                          0.275545         2.176091        1.098612
# 4                          1.000000         1.755875        0.693147
# ..                              ...              ...             ...
# 488                        0.383380         2.004321        1.945910
# 489                        0.299295         2.004321        1.945910
# 490                        0.156368         2.004321        1.945910
# 491                        0.090641         2.004321        1.945910
# 492                        0.056384         2.004321        1.945910
#
#     wrapperRelevance
# 0                 no
# 1                yes
# 2                 no
# 3                 no
# 4                yes
# ..               ...
# 488              yes
# 489               no
# 490               no
# 491               no
# 492               no
#
# [493 rows x 15 columns]

# %%
# target features
y = data_set.iloc[:,-1]

# Encode categorical target values
le = preprocessing.LabelEncoder()
le.fit(y)
y = le.transform(y)
y = pd.DataFrame(y)

#dependent variables
X = data_set.iloc[:,3:-1] 
# X = data_set.iloc[:29,3:-1]   #test

# Group used in cross-validation accordind to original dataset
groups = data_set.iloc[:,:].datasetName
# groups = data_set.iloc[:29,:].datasetName  #test

#Attributes
attributes = data_set.iloc[:,:].attributeName

#All datasets that will be in test set each run
test_cols =list(groups.unique())

# %%
for i in groups.unique():
    exec('dataset_{KEY} = pd.read_pickle("data\processed\dataset_{KEY}.pkl")'.format(KEY = i))

# %%
# Supressing warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## HistGradientBoostingClassifier Parameters

# %%
# parameters 
c_max_iter =["max_iter=100", "max_iter=1000"]
c_max_depth =["max_depth=None","max_depth=4", "max_depth=6","max_depth=8"]
c_min_samples_leaf = ["min_samples_leaf=10" ,"min_samples_leaf=20" ]
c_learning_rate= ["learning_rate=0.01", "learning_rate=0.1"] 
a = list(product(c_max_iter,c_max_depth,c_min_samples_leaf,c_learning_rate))
d=[]
for i in a:    
         c ='HistGradientBoostingClassifier('+ ','.join(i)+')'
         d.append(c)
d = [t.replace('"', '') for t in d]
hist_parameters =[]
for i in d:
    hist_parameters.append(eval(i))
hist_parameters
# Out:
# [HistGradientBoostingClassifier(learning_rate=0.01, min_samples_leaf=10),
#  HistGradientBoostingClassifier(min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01),
#  HistGradientBoostingClassifier(),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=4, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4),
#  HistGradientBoostingClassifier(max_depth=4),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=6, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6),
#  HistGradientBoostingClassifier(max_depth=6),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=8, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8),
#  HistGradientBoostingClassifier(max_depth=8),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_iter=1000,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_iter=1000, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_iter=1000),
#  HistGradientBoostingClassifier(max_iter=1000),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4, max_iter=1000,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=4, max_iter=1000, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4, max_iter=1000),
#  HistGradientBoostingClassifier(max_depth=4, max_iter=1000),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6, max_iter=1000,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=6, max_iter=1000, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6, max_iter=1000),
#  HistGradientBoostingClassifier(max_depth=6, max_iter=1000),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8, max_iter=1000,
#                                 min_samples_leaf=10),
#  HistGradientBoostingClassifier(max_depth=8, max_iter=1000, min_samples_leaf=10),
#  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8, max_iter=1000),
#  HistGradientBoostingClassifier(max_depth=8, max_iter=1000)]

# %% [markdown]
# ## Modelling

# %%
pipe = ImbPipeline(
    [
        ("scaling", None),
        ("balance", None),        
        ("classifier", None),
    ]
)

param_grid = [
    {
         "scaling": ['passthrough'],
         'balance':[None],
         'classifier': hist_parameters
        }   
]


for i in test_cols:
    

    
    results_modeling = {} #ver
    
    if not os.path.isfile(f'models\\{i}_model.sav'):        
    # If model does not exist yet
    
        # Random seed used in case of replication of results
        SEED = random.randint(0,10000)
        
        
        start_time = time.time()
        
        results_modeling['dataset']= i #ver    
        results_modeling['seed']= SEED #ver

        #defining test_set
        print('\ntest_set:',i,'\n')
     
        col_test = [i]    
        test_set = data_set[data_set.datasetName.isin(col_test)].copy()
        X_test = test_set.iloc[:,3:-1]
        groups_test = test_set.iloc[:,:].datasetName

        attributes_test = test_set.iloc[:,:].attributeName 

        y_test = test_set.iloc[:,-1]
        le.fit(y_test)
        y_test = le.transform(y_test)
        y_test = pd.DataFrame(y_test,index = test_set.index)

        #defining training_set
        training_set = data_set[~data_set.datasetName.isin(col_test)].copy()
        X_training = training_set.iloc[:,3:-1]
        groups_training = training_set.iloc[:,:].datasetName
        y_training = training_set.iloc[:,-1]
        le.fit(y_training)
        y_training = le.transform(y_training)
        y_training = pd.DataFrame(y_training)

        #fitting model
        np.random.seed(SEED)
        grid = GridSearchCV(pipe, n_jobs=1, param_grid=param_grid,scoring='accuracy',cv=LeaveOneGroupOut(),return_train_score=True)
        grid.fit(X_training, y_training, groups=groups_training)
        print(grid.best_estimator_)
        print("Cross Validation Best Accuracy (validation_set):",grid.best_score_)
        
        results_modeling['CV_best_model_validation_score'] = grid.best_score_ #ver

        # save each the model to disk
        filename = f'models\\{i}_model.sav'
        exec("pickle.dump(grid.best_estimator_, open(filename, 'wb'))".format(KEY = i))



        # make predictions using the best estimator
        y_pred = grid.best_estimator_.predict(X_test)
        print("Accuracy Model Relevant Features (test_set):",  metrics.accuracy_score(y_test, y_pred))
        
        results_modeling['Accuracy_test_set'] = metrics.accuracy_score(y_test, y_pred) #ver

        # compare real values with weka and new_model predictions
        pred=pd.DataFrame()
        pred['dataset'] = groups_test
        pred = pd.DataFrame(pred)
        pred['y_test'] = y_test
        pred['y_pred'] = y_pred    
        pred['attributeName'] = attributes_test #ver

        # if model does not choose any feature, it will be forced to choose at least one
        if sum(pred.y_pred)==0:
            proba_df=pd.DataFrame(grid.best_estimator_.predict_proba(X_test))
            
            results_modeling['variaveis_new_model_test_set'] = [pred.attributeName.iloc[proba_df.iloc[:,1].idxmax()]] #ver
            results_modeling['variaveis_new_model_test_set_remove'] = list(set(list(pred.attributeName.unique())) - set(pred.attributeName.iloc[proba_df.iloc[:,1].idxmax()])) #ver

        else:
            aux = []
            aux_remove=[]    
            aux = pred[pred.y_pred==1].groupby('dataset')['attributeName'].apply(lambda x: x.tolist()).to_dict() #ver
            aux_remove = pred[pred.y_pred==0].groupby('dataset')['attributeName'].apply(lambda x: x.tolist()).to_dict() #ver

            results_modeling['variaveis_new_model_test_set'] = aux[f'{i}'] #ver
            if (len(aux_remove)>0):    #checking if there are variables to remove
                results_modeling['variaveis_new_model_test_set_remove'] = aux_remove[f'{i}'] #ver
            else:
                results_modeling['variaveis_new_model_test_set_remove'] = None 
            


        
        # Specify the filename/path where you want to save the dictionary
        filename = f'models\\results\\{i}_dict.pkl'

        # Save the dictionary to disk using pickle.dump
        with open(filename, 'wb') as file:
            pickle.dump(results_modeling, file)        
            
        end_time = time.time()
        time_spent = end_time - start_time
        print("Time spent: ", time_spent)
        results_modeling['time']= time_spent #ver 

        print('------------------------------------------------------------------------------')        
        
    else:
        print(f'The {i}_model  already exists.')
# Out:
# test_set: iris
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=8, max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.678341260416732
# Accuracy Model Relevant Features (test_set): 0.5
# Time spent:  6173.346262216568
# ------------------------------------------------------------------------------
#
# test_set: labor_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01,
#                                                 max_depth=6))])
# Cross Validation Best Accuracy (validation_set): 0.6795702724948007
# Accuracy Model Relevant Features (test_set): 0.625
# Time spent:  6006.8883101940155
# ------------------------------------------------------------------------------
#
# test_set: labor_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6686277558919068
# Accuracy Model Relevant Features (test_set): 0.625
# Time spent:  5623.013252735138
# ------------------------------------------------------------------------------
#
# test_set: glass
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6789156859911577
# Accuracy Model Relevant Features (test_set): 0.5555555555555556
# Time spent:  5639.41113615036
# ------------------------------------------------------------------------------
#
# test_set: breast_cancer
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.670000858680104
# Accuracy Model Relevant Features (test_set): 0.4444444444444444
# Time spent:  5602.786733627319
# ------------------------------------------------------------------------------
#
# test_set: contact_lenses
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6656522460767744
# Accuracy Model Relevant Features (test_set): 0.75
# Time spent:  5698.591603279114
# ------------------------------------------------------------------------------
#
# test_set: credit_g_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.677349956123541
# Accuracy Model Relevant Features (test_set): 0.6
# Time spent:  5613.880890607834
# ------------------------------------------------------------------------------
#
# test_set: credit_g_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.685323219757182
# Accuracy Model Relevant Features (test_set): 0.7
# Time spent:  6655.756684541702
# ------------------------------------------------------------------------------
#
# test_set: diabetes
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=8,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6858629839761914
# Accuracy Model Relevant Features (test_set): 0.375
# Time spent:  5607.655734539032
# ------------------------------------------------------------------------------
#
# test_set: hypothyroid_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4, max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6840008262178072
# Accuracy Model Relevant Features (test_set): 0.7
# Time spent:  5552.221946001053
# ------------------------------------------------------------------------------
#
# test_set: hypothyroid_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier', HistGradientBoostingClassifier(max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6786852036852036
# Accuracy Model Relevant Features (test_set): 0.6
# Time spent:  5555.240086078644
# ------------------------------------------------------------------------------
#
# test_set: hypothyroid_part3
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6845390982183435
# Accuracy Model Relevant Features (test_set): 0.6666666666666666
# Time spent:  5639.523062467575
# ------------------------------------------------------------------------------
#
# test_set: segment_challenge_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6760688734745338
# Accuracy Model Relevant Features (test_set): 0.9
# Time spent:  5603.149513959885
# ------------------------------------------------------------------------------
#
# test_set: segment_challenge_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6770205161714594
# Accuracy Model Relevant Features (test_set): 0.5555555555555556
# Time spent:  5556.829104423523
# ------------------------------------------------------------------------------
#
# test_set: soybean_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6696729109464958
# Accuracy Model Relevant Features (test_set): 0.8333333333333334
# Time spent:  5589.329044818878
# ------------------------------------------------------------------------------
#
# test_set: soybean_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6593529374189752
# Accuracy Model Relevant Features (test_set): 0.8333333333333334
# Time spent:  5587.430217266083
# ------------------------------------------------------------------------------
#
# test_set: soybean_part3
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier', HistGradientBoostingClassifier(max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6702184607844984
# Accuracy Model Relevant Features (test_set): 0.7272727272727273
# Time spent:  5546.664377689362
# ------------------------------------------------------------------------------
#
# test_set: vote_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6726591804421992
# Accuracy Model Relevant Features (test_set): 0.875
# Time spent:  5607.1510446071625
# ------------------------------------------------------------------------------
#
# test_set: vote_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier', HistGradientBoostingClassifier(max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6749195772780678
# Accuracy Model Relevant Features (test_set): 0.5
# Time spent:  5543.475347042084
# ------------------------------------------------------------------------------
#
# test_set: weather_nominal
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6640008314536616
# Accuracy Model Relevant Features (test_set): 1.0
# Time spent:  5497.90847325325
# ------------------------------------------------------------------------------
#
# test_set: abalone_classification
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6756226477924591
# Accuracy Model Relevant Features (test_set): 0.375
# Time spent:  5425.367248535156
# ------------------------------------------------------------------------------
#
# test_set: balance_scale
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6659618159618159
# Accuracy Model Relevant Features (test_set): 0.0
# Time spent:  5549.533607006073
# ------------------------------------------------------------------------------
#
# test_set: data_banknote_authentication
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6662175350854597
# Accuracy Model Relevant Features (test_set): 0.75
# Time spent:  5583.603579521179
# ------------------------------------------------------------------------------
#
# test_set: DishonestInternetUsers
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6605719228360737
# Accuracy Model Relevant Features (test_set): 1.0
# Time spent:  5570.533645629883
# ------------------------------------------------------------------------------
#
# test_set: ecoli
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6710313795219455
# Accuracy Model Relevant Features (test_set): 0.8571428571428571
# Time spent:  5606.388514757156
# ------------------------------------------------------------------------------
#
# test_set: hayes_roth_trainAndtest
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6663480911122419
# Accuracy Model Relevant Features (test_set): 0.5
# Time spent:  5578.934459924698
# ------------------------------------------------------------------------------
#
# test_set: hcvdat0
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6609852935324634
# Accuracy Model Relevant Features (test_set): 0.08333333333333333
# Time spent:  5585.8891677856445
# ------------------------------------------------------------------------------
#
# test_set: mammographic_masses
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=8,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6702838042460683
# Accuracy Model Relevant Features (test_set): 0.2
# Time spent:  5548.92498254776
# ------------------------------------------------------------------------------
#
# test_set: monks_1_train
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6757109242958298
# Accuracy Model Relevant Features (test_set): 0.6666666666666666
# Time spent:  5469.387077093124
# ------------------------------------------------------------------------------
#
# test_set: monks_2_train
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6789318909601926
# Accuracy Model Relevant Features (test_set): 0.5
# Time spent:  5528.569548845291
# ------------------------------------------------------------------------------
#
# test_set: wilt
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6792516445818333
# Accuracy Model Relevant Features (test_set): 0.6
# Time spent:  5533.227671861649
# ------------------------------------------------------------------------------
#
# test_set: seeds_dataset
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4, max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6725583640677981
# Accuracy Model Relevant Features (test_set): 0.5714285714285714
# Time spent:  5565.381162405014
# ------------------------------------------------------------------------------
#
# test_set: Surveillance
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01,
#                                                 max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6653818927403833
# Accuracy Model Relevant Features (test_set): 0.7142857142857143
# Time spent:  5319.3776679039
# ------------------------------------------------------------------------------
#
# test_set: wine
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=6, max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6680256064690026
# Accuracy Model Relevant Features (test_set): 0.6153846153846154
# Time spent:  5209.522003412247
# ------------------------------------------------------------------------------
#
# test_set: winequality_red_classification
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6636902405770331
# Accuracy Model Relevant Features (test_set): 0.6363636363636364
# Time spent:  5218.6111834049225
# ------------------------------------------------------------------------------
#
# test_set: winequality_white_classification
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6716478490063396
# Accuracy Model Relevant Features (test_set): 0.7272727272727273
# Time spent:  5217.65717291832
# ------------------------------------------------------------------------------
#
# test_set: ionosphere_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier', HistGradientBoostingClassifier(max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6766535613233726
# Accuracy Model Relevant Features (test_set): 0.4166666666666667
# Time spent:  5196.866852760315
# ------------------------------------------------------------------------------
#
# test_set: ionosphere_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=6,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6820024838892763
# Accuracy Model Relevant Features (test_set): 0.36363636363636365
# Time spent:  5189.778131008148
# ------------------------------------------------------------------------------
#
# test_set: ionosphere_part3
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6834430244807603
# Accuracy Model Relevant Features (test_set): 0.6363636363636364
# Time spent:  5261.9943017959595
# ------------------------------------------------------------------------------
#
# test_set: avila_tr
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000))])
# Cross Validation Best Accuracy (validation_set): 0.6646844769486279
# Accuracy Model Relevant Features (test_set): 0.9
# Time spent:  5200.015100479126
# ------------------------------------------------------------------------------
#
# test_set: avila_ts
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6703692272088498
# Accuracy Model Relevant Features (test_set): 0.9
# Time spent:  5165.184123277664
# ------------------------------------------------------------------------------
#
# test_set: cmc
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6768965049625426
# Accuracy Model Relevant Features (test_set): 0.5555555555555556
# Time spent:  5219.422529459
# ------------------------------------------------------------------------------
#
# test_set: sonar_all_data_part1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=8, max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6702077796417418
# Accuracy Model Relevant Features (test_set): 0.3333333333333333
# Time spent:  5143.836058139801
# ------------------------------------------------------------------------------
#
# test_set: sonar_all_data_part2
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier', HistGradientBoostingClassifier(max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6794395855716611
# Accuracy Model Relevant Features (test_set): 0.5
# Time spent:  5177.532332658768
# ------------------------------------------------------------------------------
#
# test_set: sonar_all_data_part3
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6869554449743128
# Accuracy Model Relevant Features (test_set): 0.4166666666666667
# Time spent:  5185.02580165863
# ------------------------------------------------------------------------------
#
# test_set: sonar_all_data_part4
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6748192583098244
# Accuracy Model Relevant Features (test_set): 0.6666666666666666
# Time spent:  5145.95475769043
# ------------------------------------------------------------------------------
#
# test_set: sonar_all_data_part5
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6693371356107204
# Accuracy Model Relevant Features (test_set): 0.4166666666666667
# Time spent:  5179.306638717651
# ------------------------------------------------------------------------------
#
# test_set: accent_mfcc_data_1
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6832846398884135
# Accuracy Model Relevant Features (test_set): 0.75
# Time spent:  5234.5794496536255
# ------------------------------------------------------------------------------
#
# test_set: EEG_Eye_State
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01,
#                                                 max_depth=4))])
# Cross Validation Best Accuracy (validation_set): 0.6932900171107718
# Accuracy Model Relevant Features (test_set): 0.35714285714285715
# Time spent:  5145.175491333008
# ------------------------------------------------------------------------------
#
# test_set: magic04
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=4,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6854710541031297
# Accuracy Model Relevant Features (test_set): 0.4
# Time spent:  5174.345848321915
# ------------------------------------------------------------------------------
#
# test_set: wifi_localization
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6679898455841853
# Accuracy Model Relevant Features (test_set): 0.7142857142857143
# Time spent:  5197.396463632584
# ------------------------------------------------------------------------------
#
# test_set: ObesityDataSet_raw_and_data_sinthetic
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=4,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6677517451102356
# Accuracy Model Relevant Features (test_set): 0.5625
# Time spent:  5106.129372119904
# ------------------------------------------------------------------------------
#
# test_set: yeast
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(max_depth=8, max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6663186132525756
# Accuracy Model Relevant Features (test_set): 0.75
# Time spent:  5192.784989833832
# ------------------------------------------------------------------------------
#
# test_set: zoo
#
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01, max_depth=8,
#                                                 max_iter=1000,
#                                                 min_samples_leaf=10))])
# Cross Validation Best Accuracy (validation_set): 0.6739820452084602
# Accuracy Model Relevant Features (test_set): 0.5625
# Time spent:  5135.86252951622
# ------------------------------------------------------------------------------
