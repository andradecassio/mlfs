# %%
import numpy as np
import pandas as pd
import os

import weka.core.jvm as jvm
from weka.core.dataset import Instances
from weka.classifiers import Classifier, Evaluation
from weka.filters import Filter
from weka.core import converters

from sklearn.model_selection import KFold
from sklearn import preprocessing

from scipy.stats import t
from math import sqrt
from statistics import stdev
import pickle

# %%
jvm.start(packages=True)

# %% [markdown]
# ## Importing data

# %%
# Moving to project directory
os.chdir('..')

# %%
data_set = pd.read_pickle("data\processed\data_set.pkl")

# %%
# target features
y = data_set.iloc[:,-1]

# Encode categorical target values
le = preprocessing.LabelEncoder()
le.fit(y)
y = le.transform(y)
y = pd.DataFrame(y)

#dependent variables
X = data_set.iloc[:,4:-1] 
# X = data_set.iloc[:29,4:-1]   #test

# Group used in cross-validation accordind to original dataset
groups = data_set.iloc[:,:].datasetName
# groups = data_set.iloc[:29,:].datasetName  #test

#Attributes
attributes = data_set.iloc[:,:].attributeName

#All datasets that will be in test set each run
test_cols =list(groups.unique())

# %%
arff_files={}
# Set the path to the folder containing ARFF files
folder_path = "data\\raw"  # Replace with your folder path

# Iterate over the files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path) and filename.endswith(".arff"):
        print("\nLoading file:", file_path)
        try:
            data = converters.load_any_file(file_path)
            
            # Perform further processing or analysis on the data
            # ...
            # Your code here
            
            # Example: Print the dataset summary
            print("Number of instances:", data.num_instances)
            print("Number of attributes:", data.num_attributes)
            print("----------------------")

            nome = filename.split("\\")[-1]
            nome = nome.replace(".arff", "")
            nome = nome.replace("-", "_")
            print(nome)
            exec('arff_files["{KEY}"] = data'.format(KEY = nome))
            
            
        except Exception as e:
            print("Error loading file:", file_path)
            print("Error message:", str(e))
# Out:
# Loading file: data\raw\abalone_classification.arff
# Number of instances: 4177
# Number of attributes: 9
# ----------------------
# abalone_classification
#
# Loading file: data\raw\accent-mfcc-data-1.arff
# Number of instances: 329
# Number of attributes: 13
# ----------------------
# accent_mfcc_data_1
#
# Loading file: data\raw\avila-tr.arff
# Number of instances: 10430
# Number of attributes: 11
# ----------------------
# avila_tr
#
# Loading file: data\raw\avila-ts.arff
# Number of instances: 10437
# Number of attributes: 11
# ----------------------
# avila_ts
#
# Loading file: data\raw\balance-scale.arff
# Number of instances: 625
# Number of attributes: 5
# ----------------------
# balance_scale
#
# Loading file: data\raw\breast-cancer.arff
# Number of instances: 286
# Number of attributes: 10
# ----------------------
# breast_cancer
#
# Loading file: data\raw\cmc.arff
# Number of instances: 1473
# Number of attributes: 10
# ----------------------
# cmc
#
# Loading file: data\raw\contact-lenses.arff
# Number of instances: 24
# Number of attributes: 5
# ----------------------
# contact_lenses
#
# Loading file: data\raw\credit-g.arff
# Number of instances: 1000
# Number of attributes: 21
# ----------------------
# credit_g
#
# Loading file: data\raw\data_banknote_authentication.arff
# Number of instances: 1372
# Number of attributes: 5
# ----------------------
# data_banknote_authentication
#
# Loading file: data\raw\diabetes.arff
# Number of instances: 768
# Number of attributes: 9
# ----------------------
# diabetes
#
# Loading file: data\raw\DishonestInternetUsers.arff
# Number of instances: 322
# Number of attributes: 5
# ----------------------
# DishonestInternetUsers
#
# Loading file: data\raw\ecoli.arff
# Number of instances: 336
# Number of attributes: 8
# ----------------------
# ecoli
#
# Loading file: data\raw\EEG_Eye_State.arff
# Number of instances: 14980
# Number of attributes: 15
# ----------------------
# EEG_Eye_State
#
# Loading file: data\raw\glass.arff
# Number of instances: 214
# Number of attributes: 10
# ----------------------
# glass
#
# Loading file: data\raw\hayes-roth_trainAndtest.arff
# Number of instances: 160
# Number of attributes: 5
# ----------------------
# hayes_roth_trainAndtest
#
# Loading file: data\raw\hcvdat0.arff
# Number of instances: 615
# Number of attributes: 13
# ----------------------
# hcvdat0
#
# Loading file: data\raw\hypothyroid.arff
# Number of instances: 3772
# Number of attributes: 30
# ----------------------
# hypothyroid
#
# Loading file: data\raw\ionosphere.arff
# Number of instances: 351
# Number of attributes: 35
# ----------------------
# ionosphere
#
# Loading file: data\raw\iris.arff
# Number of instances: 150
# Number of attributes: 5
# ----------------------
# iris
#
# Loading file: data\raw\labor.arff
# Number of instances: 57
# Number of attributes: 17
# ----------------------
# labor
#
# Loading file: data\raw\magic04.arff
# Number of instances: 19020
# Number of attributes: 11
# ----------------------
# magic04
#
# Loading file: data\raw\mammographic_masses.arff
# Number of instances: 961
# Number of attributes: 6
# ----------------------
# mammographic_masses
#
# Loading file: data\raw\monks-1_train.arff
# Number of instances: 124
# Number of attributes: 7
# ----------------------
# monks_1_train
#
# Loading file: data\raw\monks-2_train.arff
# Number of instances: 169
# Number of attributes: 7
# ----------------------
# monks_2_train
#
# Loading file: data\raw\ObesityDataSet_raw_and_data_sinthetic.arff
# Number of instances: 2111
# Number of attributes: 17
# ----------------------
# ObesityDataSet_raw_and_data_sinthetic
#
# Loading file: data\raw\seeds_dataset.arff
# Number of instances: 210
# Number of attributes: 8
# ----------------------
# seeds_dataset
#
# Loading file: data\raw\segment-challenge.arff
# Number of instances: 1500
# Number of attributes: 20
# ----------------------
# segment_challenge
#
# Loading file: data\raw\sonar_all-data.arff
# Number of instances: 208
# Number of attributes: 61
# ----------------------
# sonar_all_data
#
# Loading file: data\raw\soybean.arff
# Number of instances: 683
# Number of attributes: 36
# ----------------------
# soybean
#
# Loading file: data\raw\Surveillance.arff
# Number of instances: 14
# Number of attributes: 8
# ----------------------
# Surveillance
#
# Loading file: data\raw\vote.arff
# Number of instances: 435
# Number of attributes: 17
# ----------------------
# vote
#
# Loading file: data\raw\weather_nominal.arff
# Number of instances: 14
# Number of attributes: 5
# ----------------------
# weather_nominal
#
# Loading file: data\raw\wifi_localization.arff
# Number of instances: 2000
# Number of attributes: 8
# ----------------------
# wifi_localization
#
# Loading file: data\raw\wilt.arff
# Number of instances: 4839
# Number of attributes: 6
# ----------------------
# wilt
#
# Loading file: data\raw\wine.arff
# Number of instances: 178
# Number of attributes: 14
# ----------------------
# wine
#
# Loading file: data\raw\winequality-red_classification.arff
# Number of instances: 1599
# Number of attributes: 12
# ----------------------
# winequality_red_classification
#
# Loading file: data\raw\winequality-white_classification.arff
# Number of instances: 4898
# Number of attributes: 12
# ----------------------
# winequality_white_classification
#
# Loading file: data\raw\yeast.arff
# Number of instances: 1484
# Number of attributes: 9
# ----------------------
# yeast
#
# Loading file: data\raw\zoo.arff
# Number of instances: 101
# Number of attributes: 17
# ----------------------
# zoo

# %%
# Set the path to the folder containing ARFF files
folder_path = "data\\interim"  # Replace with your folder path

# Iterate over the files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path) and filename.endswith(".arff"):
        print("\nLoading file:", file_path)
        try:
            data = converters.load_any_file(file_path)
            
            # Perform further processing or analysis on the data
            # ...
            # Your code here
            
            # Example: Print the dataset summary
            print("Number of instances:", data.num_instances)
            print("Number of attributes:", data.num_attributes)
            print("----------------------")

            nome = filename.split("\\")[-1]
            nome = nome.replace(".arff", "")
            nome = nome.replace("-", "_")
            print(nome)
            exec('arff_files["{KEY}"] = data'.format(KEY = nome))
            
            
        except Exception as e:
            print("Error loading file:", file_path)
            print("Error message:", str(e))
# Out:
# Loading file: data\interim\credit_g_part1.arff
# Number of instances: 1000
# Number of attributes: 11
# ----------------------
# credit_g_part1
#
# Loading file: data\interim\credit_g_part2.arff
# Number of instances: 1000
# Number of attributes: 11
# ----------------------
# credit_g_part2
#
# Loading file: data\interim\hypothyroid_part1.arff
# Number of instances: 3772
# Number of attributes: 11
# ----------------------
# hypothyroid_part1
#
# Loading file: data\interim\hypothyroid_part2.arff
# Number of instances: 3772
# Number of attributes: 11
# ----------------------
# hypothyroid_part2
#
# Loading file: data\interim\hypothyroid_part3.arff
# Number of instances: 3772
# Number of attributes: 10
# ----------------------
# hypothyroid_part3
#
# Loading file: data\interim\ionosphere_part1.arff
# Number of instances: 351
# Number of attributes: 13
# ----------------------
# ionosphere_part1
#
# Loading file: data\interim\ionosphere_part2.arff
# Number of instances: 351
# Number of attributes: 12
# ----------------------
# ionosphere_part2
#
# Loading file: data\interim\ionosphere_part3.arff
# Number of instances: 351
# Number of attributes: 12
# ----------------------
# ionosphere_part3
#
# Loading file: data\interim\labor_part1.arff
# Number of instances: 57
# Number of attributes: 9
# ----------------------
# labor_part1
#
# Loading file: data\interim\labor_part2.arff
# Number of instances: 57
# Number of attributes: 9
# ----------------------
# labor_part2
#
# Loading file: data\interim\segment_challenge_part1.arff
# Number of instances: 1500
# Number of attributes: 11
# ----------------------
# segment_challenge_part1
#
# Loading file: data\interim\segment_challenge_part2.arff
# Number of instances: 1500
# Number of attributes: 10
# ----------------------
# segment_challenge_part2
#
# Loading file: data\interim\sonar_all_data_part1.arff
# Number of instances: 208
# Number of attributes: 13
# ----------------------
# sonar_all_data_part1
#
# Loading file: data\interim\sonar_all_data_part2.arff
# Number of instances: 208
# Number of attributes: 13
# ----------------------
# sonar_all_data_part2
#
# Loading file: data\interim\sonar_all_data_part3.arff
# Number of instances: 208
# Number of attributes: 13
# ----------------------
# sonar_all_data_part3
#
# Loading file: data\interim\sonar_all_data_part4.arff
# Number of instances: 208
# Number of attributes: 13
# ----------------------
# sonar_all_data_part4
#
# Loading file: data\interim\sonar_all_data_part5.arff
# Number of instances: 208
# Number of attributes: 13
# ----------------------
# sonar_all_data_part5
#
# Loading file: data\interim\soybean_part1.arff
# Number of instances: 683
# Number of attributes: 13
# ----------------------
# soybean_part1
#
# Loading file: data\interim\soybean_part2.arff
# Number of instances: 683
# Number of attributes: 13
# ----------------------
# soybean_part2
#
# Loading file: data\interim\soybean_part3.arff
# Number of instances: 683
# Number of attributes: 12
# ----------------------
# soybean_part3
#
# Loading file: data\interim\vote_part1.arff
# Number of instances: 435
# Number of attributes: 9
# ----------------------
# vote_part1
#
# Loading file: data\interim\vote_part2.arff
# Number of instances: 435
# Number of attributes: 9
# ----------------------
# vote_part2

# %%
for i in groups.unique():
    exec('dataset_{KEY} = pd.read_pickle("data\processed\dataset_{KEY}.pkl")'.format(KEY = i))

# %%
variaveis_weka = data_set[data_set.wrapperRelevance=='yes'].iloc[:,1:3].groupby('datasetName')['attributeName'].apply(lambda x: x.tolist()).to_dict()
variaveis_weka_remove = data_set[data_set.wrapperRelevance=='no'].iloc[:,1:3].groupby('datasetName')['attributeName'].apply(lambda x: x.tolist()).to_dict()

# %%
variaveis_new_model_test_set = {}
variaveis_new_model_test_set_remove = {}
CV_best_model_validation_score = {}

accuracy_aux = 0


# Specify the folder where the dictionaries are stored
folder_path = 'models\\results'

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.pkl'):
        file_path = os.path.join(folder_path, filename)

        # Load the dictionary from the file using pickle.load
        with open(file_path, 'rb') as file:
            loaded_dict = pickle.load(file)
        
        aux={}
        aux[loaded_dict['dataset']]=loaded_dict['variaveis_new_model_test_set']             
        variaveis_new_model_test_set.update(aux)
        
        aux={}
        aux[loaded_dict['dataset']]=loaded_dict['variaveis_new_model_test_set_remove']             
        variaveis_new_model_test_set_remove.update(aux)        

        aux={}
        aux[loaded_dict['dataset']]=loaded_dict['CV_best_model_validation_score']             
        CV_best_model_validation_score.update(aux)          
        
        #storing best model overall
        if accuracy_aux < loaded_dict['CV_best_model_validation_score']:
            best_model = loaded_dict['dataset']
            accuracy_aux = loaded_dict['CV_best_model_validation_score']

# %%
 # load the model from disk
# os.chdir('models')
filename = f'models\\{best_model}_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model

# save each the model to disk
filename = f'models\\best_model.sav'
pickle.dump(loaded_model, open(filename, 'wb'))

# %%
# Python implementation of the Nadeau and Bengio correction of dependent Student's t-test (https://gist.github.com/jensdebruijn/13e8eeda85eb8644ac2a4ac4c3b8e732)
# using the equation stated in https://www.cs.waikato.ac.nz/~eibe/pubs/bouckaert_and_frank.pdf
def corrected_dependent_ttest(data1, data2, n_training_samples, n_test_samples, alpha):
    """
    data1: accuracies WRAPPER model
    data2: accuracies NEW model
    
    """
    n = len(data1)
    differences = [(data1[i]-data2[i]) for i in range(n)]
    sd = stdev(differences)
    divisor = 1 / n * sum(differences)
    test_training_ratio = n_test_samples / n_training_samples
    denominator = sqrt(1 / n + test_training_ratio) * sd
    t_stat = divisor / denominator
    # degrees of freedom
    df = n - 1
    # calculate the critical value
    cv = t.ppf(1.0 - alpha, df)
    # calculate the p-value
    p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
    # return everything
    return t_stat, df, cv, p

# %%
col31 = []
col32 = []
col33 = []

classifier_weka = Classifier(classname="weka.classifiers.functions.SimpleLogistic")

n_train={}
n_test={}
ten_tencv_corrected_t_test={}
scores_weka = {}
scores_new = {}
scores_complete = {}

for i in test_cols:
    print(i)
    

    col31.append(i)
    
    # real data values to ajust a logistic regression model     
    exec('X = dataset_{KEY}.iloc[:,:-1]'.format(KEY = i))


    exec('X_weka = X.loc[:, variaveis_weka["{KEY}"]]'.format(KEY = i))
    exec('X_new = X.loc[:, variaveis_new_model_test_set["{KEY}"]]'.format(KEY = i)) #ver
    
    exec('print("WEKA:",variaveis_weka["{KEY}"])'.format(KEY = i))
    exec('print("New Model:",variaveis_new_model_test_set["{KEY}"])'.format(KEY = i))

    # loading arff_files
    
    exec('dataset_arff = arff_files["{KEY}"]'.format(KEY = i))
    
    # Complete dataset    

    dataset0 = Instances.copy_instances(dataset_arff)  # Copy instances from dataset
    dataset0.class_is_last()   # set class attribute
   
    
    # WEKA subset
    try:
        exec('lista_weka = variaveis_weka_remove["{KEY}"]'.format(KEY = i))
        for p,remove in enumerate(lista_weka):
            if p==0:
                dataset1 = Instances.copy_instances(dataset_arff)  # Copy instances from dataset1

                dataset1.class_is_last()   # set class attribute
            remove = Filter(classname="weka.filters.unsupervised.attribute.RemoveByName", options=["-E", remove])
            remove.inputformat(dataset1)
            dataset1 = remove.filter(dataset1)
    
    except:
        dataset1 = Instances.copy_instances(dataset_arff)
        dataset1.class_is_last()
    
    wrapper_subset = [attr.name for attr in dataset1.attributes()]


    # Model subset
    try:
        exec('lista_weka = variaveis_new_model_test_set_remove["{KEY}"]'.format(KEY = i))
        for p,remove in enumerate(lista_weka):
            if p==0:
                dataset2 = Instances.copy_instances(dataset_arff)  # Copy instances from dataset1
                dataset2.class_is_last()   # set class attribute
            remove = Filter(classname="weka.filters.unsupervised.attribute.RemoveByName", options=["-E", remove])
            remove.inputformat(dataset2)
            dataset2 = remove.filter(dataset2)

    except:
        dataset2 = Instances.copy_instances(dataset_arff)  
        dataset2.class_is_last()  
    
    model_subset = [attr.name for attr in dataset2.attributes()]


    col32.append(len(variaveis_weka[f"{i}"])/(dataset_arff.num_attributes-1))
    col33.append(len(variaveis_new_model_test_set[f"{i}"])/(dataset_arff.num_attributes-1))

  
    
    num_runs = 10
    num_folds = 10
    kf = KFold(n_splits=num_folds, shuffle=True)
    score_weka_aux=[]
    score_new_aux=[]
    score_complete_aux=[]       
    
        
    for run in np.arange(num_runs):

        # Perform cross-validation on the datasets
        iteration=1
        for train_indices, test_indices in kf.split(dataset_arff):

            
            train_set0 = Instances.copy_instances(dataset0)  # Copy instances from dataset1
            test_set0 = Instances.copy_instances(dataset0)   # Copy instances from dataset1
            
            train_set1 = Instances.copy_instances(dataset1)  # Copy instances from dataset1
            test_set1 = Instances.copy_instances(dataset1)   # Copy instances from dataset1

            train_set2 = Instances.copy_instances(dataset2)  # Copy instances from dataset2
            test_set2 = Instances.copy_instances(dataset2)   # Copy instances from dataset2

            # Set instances indices for training and testing sets
            train_set0.delete()
            train_set1.delete()
            train_set2.delete()
            test_set0.delete()
            test_set1.delete()
            test_set2.delete()

            for index in train_indices:
                train_set0.add_instance(dataset0.get_instance(index))
                train_set1.add_instance(dataset1.get_instance(index))
                train_set2.add_instance(dataset2.get_instance(index))

            for index in test_indices:
                test_set0.add_instance(dataset0.get_instance(index))
                test_set1.add_instance(dataset1.get_instance(index))
                test_set2.add_instance(dataset2.get_instance(index))

            # Build and evaluate model on complete dataset
            classifier_weka.build_classifier(train_set0)    
            evaluation0 = Evaluation(train_set0)
            evaluation0.test_model(classifier_weka, test_set0)
            score_complete_aux.append(evaluation0.percent_correct)                

            # Build and evaluate model on Wrapper Subset
            classifier_weka.build_classifier(train_set1)    
            evaluation1 = Evaluation(train_set1)
            evaluation1.test_model(classifier_weka, test_set1)
            score_weka_aux.append(evaluation1.percent_correct)


            # Build and evaluate model on New Model Subset
            classifier_weka.build_classifier(train_set2)
            evaluation2 = Evaluation(train_set2)
            evaluation2.test_model(classifier_weka, test_set2)
            score_new_aux.append(evaluation2.percent_correct)
            iteration=iteration+1

    exec('n_train["{KEY}"] = len(train_indices)'.format(KEY = i))
    exec('n_test["{KEY}"] = len(test_indices)'.format(KEY = i))
    exec('scores_weka["{KEY}"] = score_weka_aux'.format(KEY = i))
    exec('scores_new["{KEY}"] = score_new_aux'.format(KEY = i))
    exec('scores_complete["{KEY}"] = score_complete_aux'.format(KEY = i))    
    score_weka_aux=[]
    score_new_aux=[]
    score_complete_aux =[]   

    exec('dif = (np.array(scores_new["{KEY}"]) - np.array(scores_weka["{KEY}"]))'.format(KEY = i))
    exec('dif2 = (np.array(scores_new["{KEY}"]) - np.array(scores_complete["{KEY}"]))'.format(KEY = i))    
    
    if wrapper_subset==model_subset:
        exec('ten_tencv_corrected_t_test["{KEY}"]= [np.nan,np.nan,np.nan,1]'.format(KEY = i))
        print("Model subset equals Wrapper subset")    
        print('------------------------------------------------------------------------------------------------')
    
    elif np.sum(dif)==0:
        exec('ten_tencv_corrected_t_test["{KEY}"]= [np.nan,np.nan,np.nan,1]'.format(KEY = i))
        print("Model subset differs Wrapper subset, but they had same predicitons")
        print('------------------------------------------------------------------------------------------------')
        
    else:
        exec('ten_tencv_corrected_t_test["{KEY}"]= corrected_dependent_ttest(scores_weka["{KEY}"],scores_new["{KEY}"],n_train["{KEY}"],n_test["{KEY}"],0.05)'.format(KEY = i))  
        exec('print("10x10CV corrected paired t test:",ten_tencv_corrected_t_test["{KEY}"])'.format(KEY = i))    
        print('------------------------------------------------------------------------------------------------')
# Out:
# iris
# WEKA: ['petalwidth']
# New Model: ['petallength']
# 10x10CV corrected paired t test: (0.35879704526413525, 99, 1.6603911559963895, 0.7205109646088039)
# ------------------------------------------------------------------------------------------------
# labor_part1
# WEKA: ['wage-increase-second-year', 'longterm-disability-assistance', 'duration']
# New Model: ['wage-increase-second-year', 'statutory-holidays', 'longterm-disability-assistance', 'pension']
# 10x10CV corrected paired t test: (0.3411429770763928, 99, 1.6603911559963895, 0.7337189075221424)
# ------------------------------------------------------------------------------------------------
# labor_part2
# WEKA: ['wage-increase-first-year', 'contribution-to-health-plan', 'working-hours']
# New Model: ['wage-increase-first-year', 'contribution-to-dental-plan']
# 10x10CV corrected paired t test: (1.8066367603555484, 99, 1.6603911559963895, 0.07385688532663393)
# ------------------------------------------------------------------------------------------------
# glass
# WEKA: ['K', 'Al', 'Ba', 'Mg', 'Na', 'Fe']
# New Model: ['K', 'Al', 'Ba', 'Mg', 'Ca', 'Na', 'RI', 'Si']
# 10x10CV corrected paired t test: (0.8980320903112482, 99, 1.6603911559963895, 0.37134729332071803)
# ------------------------------------------------------------------------------------------------
# breast_cancer
# WEKA: ['deg-malig', 'inv-nodes', 'menopause']
# New Model: ['deg-malig', 'inv-nodes', 'node-caps', 'tumor-size', 'age', 'breast-quad', 'breast', 'menopause']
# 10x10CV corrected paired t test: (0.6944589809493124, 99, 1.6603911559963895, 0.48902095248757504)
# ------------------------------------------------------------------------------------------------
# contact_lenses
# WEKA: ['tear-prod-rate', 'astigmatism']
# New Model: ['tear-prod-rate']
# 10x10CV corrected paired t test: (2.0154907395369484, 99, 1.6603911559963895, 0.04656365726315981)
# ------------------------------------------------------------------------------------------------
# credit_g_part1
# WEKA: ['checking_status', 'credit_history', 'credit_amount', 'age', 'personal_status']
# New Model: ['checking_status', 'credit_history', 'housing']
# 10x10CV corrected paired t test: (2.197250825188459, 99, 1.6603911559963895, 0.030334582309727187)
# ------------------------------------------------------------------------------------------------
# credit_g_part2
# WEKA: ['duration', 'savings_status', 'purpose', 'installment_commitment']
# New Model: ['duration', 'savings_status', 'purpose', 'property_magnitude', 'foreign_worker', 'installment_commitment', 'existing_credits']
# 10x10CV corrected paired t test: (1.266788841097728, 99, 1.6603911559963895, 0.20820299083495164)
# ------------------------------------------------------------------------------------------------
# diabetes
# WEKA: ['plas', 'age', 'mass', 'skin', 'preg', 'pedi', 'pres']
# New Model: ['plas', 'mass']
# 10x10CV corrected paired t test: (0.28320882158270083, 99, 1.6603911559963895, 0.7776081268122552)
# ------------------------------------------------------------------------------------------------
# hypothyroid_part1
# WEKA: ['TT4', 'query_hypothyroid', 'psych', 'FTI_measured', 'goitre', 'age']
# New Model: ['TT4', 'query_hypothyroid', 'T3_measured', 'psych', 'FTI_measured', 'pregnant', 'goitre', 'query_on_thyroxine', 'age']
# 10x10CV corrected paired t test: (0.3390813506525957, 99, 1.6603911559963895, 0.7352666388778282)
# ------------------------------------------------------------------------------------------------
# hypothyroid_part2
# WEKA: ['FTI', 'T3', 'TSH_measured', 'sex', 'thyroid_surgery', 'tumor']
# New Model: ['FTI', 'T3', 'TSH_measured', 'referral_source', 'sex', 'T4U_measured', 'on_antithyroid_medication', 'tumor']
# 10x10CV corrected paired t test: (1.0321352223855875, 99, 1.6603911559963895, 0.3045236458196521)
# ------------------------------------------------------------------------------------------------
# hypothyroid_part3
# WEKA: ['TSH', 'on_thyroxine', 'TT4_measured', 'sick', 'I131_treatment']
# New Model: ['TSH', 'on_thyroxine', 'TT4_measured', 'lithium']
# 10x10CV corrected paired t test: (-0.03809401088401163, 99, 1.6603911559963895, 0.9696894379015824)
# ------------------------------------------------------------------------------------------------
# segment_challenge_part1
# WEKA: ['rawred-mean', 'hue-mean', 'value-mean', 'rawgreen-mean', 'exblue-mean', 'short-line-density-2']
# New Model: ['hue-mean', 'value-mean', 'rawgreen-mean', 'exblue-mean', 'short-line-density-2']
# 10x10CV corrected paired t test: (6.842359392063325, 99, 1.6603911559963895, 6.551870157522899e-10)
# ------------------------------------------------------------------------------------------------
# segment_challenge_part2
# WEKA: ['rawblue-mean', 'exgreen-mean', 'saturation-mean', 'region-centroid-row', 'exred-mean']
# New Model: ['intensity-mean', 'rawblue-mean', 'exgreen-mean', 'saturation-mean', 'region-centroid-row', 'exred-mean', 'hedge-mean', 'vedge-mean', 'short-line-density-5']
# 10x10CV corrected paired t test: (0.47985654918079995, 99, 1.6603911559963895, 0.6323878741655484)
# ------------------------------------------------------------------------------------------------
# soybean_part1
# WEKA: ['fruit-pods', 'canker-lesion', 'leafspots-halo', 'date', 'stem', 'temp', 'mold-growth', 'area-damaged', 'germination']
# New Model: ['fruit-pods', 'canker-lesion', 'leafspots-halo', 'date', 'stem', 'temp', 'mold-growth', 'area-damaged', 'shriveling', 'leaf-shread', 'germination']
# 10x10CV corrected paired t test: (0.30892714678054906, 99, 1.6603911559963895, 0.7580261289387389)
# ------------------------------------------------------------------------------------------------
# soybean_part2
# WEKA: ['int-discolor', 'fruit-spots', 'roots', 'leafspots-marg', 'plant-growth', 'leaf-malf', 'seed-discolor', 'severity', 'plant-stand', 'lodging']
# New Model: ['int-discolor', 'fruit-spots', 'roots', 'leafspots-marg', 'plant-growth', 'leaf-malf', 'seed-discolor', 'fruiting-bodies', 'severity', 'plant-stand', 'lodging', 'hail']
# 10x10CV corrected paired t test: (1.3777888707385597, 99, 1.6603911559963895, 0.17137498058264877)
# ------------------------------------------------------------------------------------------------
# soybean_part3
# WEKA: ['leaf-mild', 'leafspot-size', 'stem-cankers', 'sclerotia', 'precip', 'external-decay', 'leaves', 'seed-size', 'seed', 'seed-tmt']
# New Model: ['leaf-mild', 'leafspot-size', 'stem-cankers', 'sclerotia', 'precip', 'external-decay', 'leaves', 'crop-hist', 'seed-tmt']
# 10x10CV corrected paired t test: (4.433755127703888, 99, 1.6603911559963895, 2.3994847875963288e-05)
# ------------------------------------------------------------------------------------------------
# vote_part1
# WEKA: ['adoption-of-the-budget-resolution', 'el-salvador-aid', 'superfund-right-to-sue', 'anti-satellite-test-ban', 'duty-free-exports', 'synfuels-corporation-cutback']
# New Model: ['adoption-of-the-budget-resolution', 'el-salvador-aid', 'superfund-right-to-sue', 'duty-free-exports', 'synfuels-corporation-cutback']
# 10x10CV corrected paired t test: (0.24520537827512234, 99, 1.6603911559963895, 0.8068049820520224)
# ------------------------------------------------------------------------------------------------
# vote_part2
# WEKA: ['physician-fee-freeze']
# New Model: ['physician-fee-freeze', 'education-spending', 'aid-to-nicaraguan-contras', 'crime', 'religious-groups-in-schools']
# 10x10CV corrected paired t test: (0.2890440486553668, 99, 1.6603911559963895, 0.7731520677854258)
# ------------------------------------------------------------------------------------------------
# weather_nominal
# WEKA: ['outlook', 'humidity']
# New Model: ['outlook', 'humidity']
# Model subset equals Wrapper subset
# ------------------------------------------------------------------------------------------------
# abalone_classification
# WEKA: ['ShuckedWeight', 'WholeWeight', 'Length']
# New Model: ['Diameter', 'ShellWeight', 'ShuckedWeight', 'WholeWeight', 'VisceraWeight', 'Length', 'Height', 'Sex']
# 10x10CV corrected paired t test: (1.7498967699885641, 99, 1.6603911559963895, 0.08323459037079095)
# ------------------------------------------------------------------------------------------------
# balance_scale
# WEKA: ['Right-Distance', 'Right-Weight', 'Left-Distance', 'Left-Weight']
# New Model: ['Right-Distance', 'Right-Weight', 'Left-Distance', 'Left-Weight']
# Model subset equals Wrapper subset
# ------------------------------------------------------------------------------------------------
# data_banknote_authentication
# WEKA: ['varWaveletTransfImage', 'SkewnessWaveletTransfImage', 'CurtWaveletTransfImage']
# New Model: ['varWaveletTransfImage', 'SkewnessWaveletTransfImage']
# 10x10CV corrected paired t test: (11.161918160118287, 99, 1.6603911559963895, 0.0)
# ------------------------------------------------------------------------------------------------
# DishonestInternetUsers
# WEKA: ['TC', 'LT', 'CT']
# New Model: ['TC', 'LT', 'CT']
# Model subset equals Wrapper subset
# ------------------------------------------------------------------------------------------------
# ecoli
# WEKA: ['alm1', 'mcg', 'alm2', 'aac', 'gvh']
# New Model: ['alm1', 'mcg', 'alm2', 'aac', 'lip', 'gvh']
# 10x10CV corrected paired t test: (-1.4517504759445392, 99, 1.6603911559963895, 0.14973272290850148)
# ------------------------------------------------------------------------------------------------
# hayes_roth_trainAndtest
# WEKA: ['age', 'educationalLevel', 'maritalStatus', 'hobby']
# New Model: ['age', 'maritalStatus']
# 10x10CV corrected paired t test: (5.115443466442002, 99, 1.6603911559963895, 1.5344765751379441e-06)
# ------------------------------------------------------------------------------------------------
# hcvdat0
# WEKA: ['ALB', 'PROT', 'AST', 'ALT', 'CHE', 'BIL', 'ALP', 'Age', 'GGT', 'CREA', 'CHOL', 'Sex']
# New Model: ['ALB', 'PROT', 'AST', 'ALT', 'CHE', 'BIL', 'ALP', 'Age', 'GGT', 'CHOL', 'Sex']
# 10x10CV corrected paired t test: (1.326976496331328, 99, 1.6603911559963895, 0.1875689060911483)
# ------------------------------------------------------------------------------------------------
# mammographic_masses
# WEKA: ['BI-RADS', 'Shape', 'Margin', 'Age', 'Density']
# New Model: ['BI-RADS', 'Shape', 'Margin', 'Age']
# 10x10CV corrected paired t test: (-0.43537534641254527, 99, 1.6603911559963895, 0.6642377285267846)
# ------------------------------------------------------------------------------------------------
# monks_1_train
# WEKA: ['a5']
# New Model: ['a5', 'a1', 'a2']
# 10x10CV corrected paired t test: (0.4214709345528373, 99, 1.6603911559963895, 0.6743249424166438)
# ------------------------------------------------------------------------------------------------
# monks_2_train
# WEKA: ['a5', 'a4', 'a1', 'a3']
# New Model: ['a5', 'a4', 'a6']
# 10x10CV corrected paired t test: (0.002364186845379576, 99, 1.6603911559963895, 0.9981184110029979)
# ------------------------------------------------------------------------------------------------
# wilt
# WEKA: ['Mean_Red', 'Mean_Green', 'Mean_NIR']
# New Model: ['Mean_Red', 'Mean_Green', 'Mean_NIR', 'SD_pan', 'GLCM_pan']
# 10x10CV corrected paired t test: (-0.017075022445036024, 99, 1.6603911559963895, 0.9864111300023393)
# ------------------------------------------------------------------------------------------------
# seeds_dataset
# WEKA: ['lenKernel', 'lenKernelGroove']
# New Model: ['areaA', 'perimeterP', 'widKernel', 'lenKernel', 'lenKernelGroove']
# 10x10CV corrected paired t test: (1.5153069113428284, 99, 1.6603911559963895, 0.1328811282016078)
# ------------------------------------------------------------------------------------------------
# Surveillance
# WEKA: ['A01']
# New Model: ['A01', 'A03', 'A02']
# 10x10CV corrected paired t test: (1.0554294998610965, 99, 1.6603911559963895, 0.29379780284197654)
# ------------------------------------------------------------------------------------------------
# wine
# WEKA: ['Flavanoids', 'Proline', 'OD280perOD315_DilutedWines', 'Hue', 'Alcohol', 'Malicacid', 'AlcalinityofAsh', 'Ash']
# New Model: ['Flavanoids', 'Proline', 'ColorIntensity', 'OD280perOD315_DilutedWines', 'Hue', 'Alcohol', 'Proanthocyanins', 'NonflavanoidPhenols', 'Ash']
# 10x10CV corrected paired t test: (1.3749164121364514, 99, 1.6603911559963895, 0.17226114725832042)
# ------------------------------------------------------------------------------------------------
# winequality_red_classification
# WEKA: ['alcohol', 'volatile_acidity', 'sulphates', 'total_sulfur_dioxide', 'chlorides', 'residual_sugar', 'pH', 'free_sulfur_dioxide']
# New Model: ['alcohol', 'volatile_acidity', 'sulphates', 'citric_acid', 'total_sulfur_dioxide', 'density', 'chlorides', 'fixed_acidity', 'pH', 'free_sulfur_dioxide']
# 10x10CV corrected paired t test: (0.09738084110473004, 99, 1.6603911559963895, 0.9226208378562044)
# ------------------------------------------------------------------------------------------------
# winequality_white_classification
# WEKA: ['alcohol', 'free_sulfur_dioxide', 'density', 'residual_sugar', 'volatile_acidity', 'citric_acid', 'pH', 'sulphates', 'fixed_acidity']
# New Model: ['alcohol', 'free_sulfur_dioxide', 'density', 'chlorides', 'residual_sugar', 'volatile_acidity', 'citric_acid', 'total_sulfur_dioxide', 'sulphates', 'fixed_acidity']
# 10x10CV corrected paired t test: (1.3105572203242832, 99, 1.6603911559963895, 0.19303966461135902)
# ------------------------------------------------------------------------------------------------
# ionosphere_part1
# WEKA: ['a34', 'a07', 'a04', 'a25', 'a28', 'a19', 'a10', 'a01']
# New Model: ['a34', 'a22', 'a07', 'a13', 'a31', 'a04', 'a16', 'a25', 'a01']
# 10x10CV corrected paired t test: (1.4984638682637512, 99, 1.6603911559963895, 0.13719471784461956)
# ------------------------------------------------------------------------------------------------
# ionosphere_part2
# WEKA: ['a05', 'a29', 'a08', 'a20', 'a32']
# New Model: ['a05', 'a17', 'a11', 'a14', 'a20', 'a26']
# 10x10CV corrected paired t test: (-0.08033458322507629, 99, 1.6603911559963895, 0.9361333278763491)
# ------------------------------------------------------------------------------------------------
# ionosphere_part3
# WEKA: ['a06', 'a21', 'a03', 'a27', 'a15', 'a18']
# New Model: ['a06', 'a33', 'a21', 'a03', 'a27', 'a15', 'a12', 'a09', 'a24', 'a18']
# 10x10CV corrected paired t test: (0.44153726376903485, 99, 1.6603911559963895, 0.6597869839617405)
# ------------------------------------------------------------------------------------------------
# avila_tr
# WEKA: ['F4', 'F3', 'F1', 'F5', 'F7', 'F9', 'F6', 'F10', 'F8']
# New Model: ['F4', 'F3', 'F1', 'F5', 'F7', 'F9', 'F6', 'F10']
# 10x10CV corrected paired t test: (2.3185835883929125, 99, 1.6603911559963895, 0.0224742036007608)
# ------------------------------------------------------------------------------------------------
# avila_ts
# WEKA: ['F4', 'F3', 'F1', 'F5', 'F9', 'F7', 'F6', 'F10', 'F8']
# New Model: ['F4', 'F3', 'F2', 'F1', 'F5', 'F9', 'F7', 'F6', 'F10', 'F8']
# 10x10CV corrected paired t test: (1.4286054279941292, 99, 1.6603911559963895, 0.1562651539932427)
# ------------------------------------------------------------------------------------------------
# cmc
# WEKA: ['NofChildrenBorn', 'WifesEducation', 'WifesAge', 'HusbandsEducation']
# New Model: ['NofChildrenBorn', 'WifesEducation', 'WifesAge', 'HusbandsEducation', 'StandardLiving', 'MediaExposure', 'WifesReligion', 'WifesNowWorking']
# 10x10CV corrected paired t test: (0.3348900746038622, 99, 1.6603911559963895, 0.7384165293161058)
# ------------------------------------------------------------------------------------------------
# sonar_all_data_part1
# WEKA: ['s11', 's36', 's46', 's6']
# New Model: ['s11', 's51', 's21', 's6', 's16', 's56', 's31', 's1']
# 10x10CV corrected paired t test: (1.5165594594879168, 99, 1.6603911559963895, 0.13256465089260416)
# ------------------------------------------------------------------------------------------------
# sonar_all_data_part2
# WEKA: ['s12', 's47', 's17', 's22', 's32', 's2']
# New Model: ['s12', 's47', 's52', 's22', 's27', 's37']
# 10x10CV corrected paired t test: (0.5694013191221835, 99, 1.6603911559963895, 0.5703735216713022)
# ------------------------------------------------------------------------------------------------
# sonar_all_data_part3
# WEKA: ['s48', 's8', 's23', 's58', 's38', 's33']
# New Model: ['s13', 's48', 's8', 's43', 's3']
# 10x10CV corrected paired t test: (0.4155031949078553, 99, 1.6603911559963895, 0.6786727789652955)
# ------------------------------------------------------------------------------------------------
# sonar_all_data_part4
# WEKA: ['s9', 's49', 's4', 's14', 's24', 's34', 's29']
# New Model: ['s9', 's49', 's4', 's44', 's34']
# 10x10CV corrected paired t test: (0.7082493850621296, 99, 1.6603911559963895, 0.4804546648059058)
# ------------------------------------------------------------------------------------------------
# sonar_all_data_part5
# WEKA: ['s10', 's45', 's5', 's20', 's35', 's15', 's60', 's30']
# New Model: ['s10', 's45', 's35', 's40', 's50']
# 10x10CV corrected paired t test: (0.6424527699035614, 99, 1.6603911559963895, 0.522064278246599)
# ------------------------------------------------------------------------------------------------
# accent_mfcc_data_1
# WEKA: ['X10', 'X6', 'X7', 'X1', 'X4', 'X9', 'X5', 'X2', 'X3', 'X12', 'X8']
# New Model: ['X10', 'X6', 'X7', 'X1', 'X4', 'X9', 'X5', 'X11', 'X3', 'X12']
# 10x10CV corrected paired t test: (2.935727838978812, 99, 1.6603911559963895, 0.004137514698969724)
# ------------------------------------------------------------------------------------------------
# EEG_Eye_State
# WEKA: ['P7', 'AF3', 'F8', 'P8', 'T7', 'O2', 'F7', 'FC5', 'F3']
# New Model: ['O1', 'P7', 'AF3', 'AF4', 'F4', 'T8', 'FC6', 'T7', 'F7', 'F3']
# 10x10CV corrected paired t test: (5.618324288000313, 99, 1.6603911559963895, 1.7748764369329706e-07)
# ------------------------------------------------------------------------------------------------
# magic04
# WEKA: ['fAlpha', 'fLength', 'fM3Trans', 'fDist']
# New Model: ['fAlpha', 'fWidth', 'fLength', 'fM3Long', 'fM3Trans', 'fAsym', 'fConc', 'fSize', 'fConc1', 'fDist']
# 10x10CV corrected paired t test: (0.8899648659748097, 99, 1.6603911559963895, 0.3756423291006199)
# ------------------------------------------------------------------------------------------------
# wifi_localization
# WEKA: ['wifiS1', 'wifiS4', 'wifiS5', 'wifiS7', 'wifiS3', 'wifiS2']
# New Model: ['wifiS1', 'wifiS4', 'wifiS5', 'wifiS6', 'wifiS7', 'wifiS3']
# 10x10CV corrected paired t test: (1.0787280686727474, 99, 1.6603911559963895, 0.2833302355980867)
# ------------------------------------------------------------------------------------------------
# ObesityDataSet_raw_and_data_sinthetic
# WEKA: ['Weight', 'Age', 'FCVC', 'TUE', 'Height', 'Gender', 'family_history_with_overweight', 'CALC', 'FAVC', 'SMOKE']
# New Model: ['Weight', 'Age', 'FCVC', 'FAF', 'CH2O', 'TUE', 'NCP', 'Height', 'CAEC', 'Gender', 'family_history_with_overweight', 'CALC', 'MTRANS', 'FAVC', 'SCC']
# 10x10CV corrected paired t test: (1.5552084183191566, 99, 1.6603911559963895, 0.12308756870541426)
# ------------------------------------------------------------------------------------------------
# yeast
# WEKA: ['alm', 'mcg', 'gvh', 'pox', 'erl', 'mit', 'nuc']
# New Model: ['alm', 'mcg', 'gvh', 'pox', 'erl', 'mit', 'vac']
# 10x10CV corrected paired t test: (4.025092086920654, 99, 1.6603911559963895, 0.00011157559448027321)
# ------------------------------------------------------------------------------------------------
# zoo
# WEKA: ['legs', 'milk', 'feathers', 'backbone', 'hair', 'aquatic']
# New Model: ['legs', 'milk', 'feathers', 'backbone', 'toothed', 'eggs', 'hair', 'breathes', 'fins', 'tail', 'airborne', 'aquatic', 'venomous']
# 10x10CV corrected paired t test: (1.2368277487971817, 99, 1.6603911559963895, 0.21907701607886865)
# ------------------------------------------------------------------------------------------------

# %%
table3 = pd.DataFrame(
 {'Dataset': col31,
  'Wrapper': col32,
  'New Model': col33
    }
)
# table3

# %%
col22=[]
col23=[]
col24=[]
for i in scores_weka:
    # exec('print("{KEY} \tWrapper:","%0.2f"% np.mean(scores_weka["{KEY}"]),"+-","%0.2f" %np.std(scores_weka["{KEY}"]),"\t New:","%0.2f" % np.mean(scores_new["{KEY}"]),"+-","%0.2f" % np.std(scores_new["{KEY}"]),"\t","%0.2f" %ten_tencv_corrected_t_test[i][3])'.format(KEY = i))
    exec('col22.append("%0.2f"% np.mean(scores_weka["{KEY}"])+"+-"+"%0.2f" %np.std(scores_weka["{KEY}"]))'.format(KEY = i))
    exec('col23.append("%0.2f"% np.mean(scores_new["{KEY}"])+"+-"+"%0.2f" %np.std(scores_new["{KEY}"]))'.format(KEY = i))
    exec('col24.append(ten_tencv_corrected_t_test[i][3]<0.05)'.format(KEY = i))

# %%
table2 = pd.DataFrame(
 {'Dataset': col31,
  'Wrapper': col22,
  'New Model': col23,
  'Difference': col24,  
    }
)
# table2

# %%
ten_tencv_corrected_t_test2={}
for j in scores_new.keys():
    exec('dif2 = (np.array(scores_new["{KEY}"]) - np.array(scores_complete["{KEY}"]))'.format(KEY = j))
#     print(j)
    if np.sum(dif2)==0:
        exec('ten_tencv_corrected_t_test2["{KEY}"]= [np.nan,np.nan,np.nan,1]'.format(KEY = j))
        # print("same predicitons")
        # print('------------------------------------------------------------------------------------------------')        
    else:
        exec('ten_tencv_corrected_t_test2["{KEY}"]= corrected_dependent_ttest(scores_new["{KEY}"],scores_complete["{KEY}"],n_train["{KEY}"],n_test["{KEY}"],0.05)'.format(KEY = j))  
        # exec('print("10x10CV corrected paired t test:",ten_tencv_corrected_t_test2["{KEY}"])'.format(KEY = j))    
        # print('------------------------------------------------------------------------------------------------')

# %%
col42=[]
col44=[]
for i in scores_weka:
    exec('col42.append("%0.2f"% np.mean(scores_complete["{KEY}"])+"+-"+"%0.2f" %np.std(scores_complete["{KEY}"]))'.format(KEY = i))
    exec('col44.append(ten_tencv_corrected_t_test2[i][3]<0.05)'.format(KEY = i))

# %%
table4 = pd.DataFrame(
 {'Dataset': col31,
  'Complete': col42,
  'New Model': col23,
  'Difference': col44,  
    }
)
# table4

# %%
#save DataFrame to pickle file
# table1.to_pickle("reports\table1.pkl")
table2.to_pickle("reports\\table2.pkl")
table3.to_pickle("reports\\table3.pkl")
table4.to_pickle("reports\\table4.pkl")
#df= pd.read_pickle("my_data.pkl")

# %% [markdown]
# ## Results
#
# ### Cross-Validation Mean Scores

# %%
# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(CV_best_model_validation_score, orient='index', columns=['Mean Score'])

# Display the DataFrame
df
# Out:
#                                        Mean Score
# abalone_classification                   0.675623
# accent_mfcc_data_1                       0.683285
# avila_tr                                 0.664684
# avila_ts                                 0.670369
# balance_scale                            0.665962
# breast_cancer                            0.670001
# cmc                                      0.676897
# contact_lenses                           0.665652
# credit_g_part1                           0.677350
# credit_g_part2                           0.685323
# data_banknote_authentication             0.666218
# diabetes                                 0.685863
# DishonestInternetUsers                   0.660572
# ecoli                                    0.671031
# EEG_Eye_State                            0.693290
# glass                                    0.678916
# hayes_roth_trainAndtest                  0.666348
# hcvdat0                                  0.660985
# hypothyroid_part1                        0.684001
# hypothyroid_part2                        0.678685
# hypothyroid_part3                        0.684539
# ionosphere_part1                         0.676654
# ionosphere_part2                         0.682002
# ionosphere_part3                         0.683443
# iris                                     0.678341
# labor_part1                              0.679570
# labor_part2                              0.668628
# magic04                                  0.685471
# mammographic_masses                      0.670284
# monks_1_train                            0.675711
# monks_2_train                            0.678932
# ObesityDataSet_raw_and_data_sinthetic    0.667752
# seeds_dataset                            0.672558
# segment_challenge_part1                  0.676069
# segment_challenge_part2                  0.677021
# sonar_all_data_part1                     0.670208
# sonar_all_data_part2                     0.679440
# sonar_all_data_part3                     0.686955
# sonar_all_data_part4                     0.674819
# sonar_all_data_part5                     0.669337
# soybean_part1                            0.669673
# soybean_part2                            0.659353
# soybean_part3                            0.670218
# Surveillance                             0.665382
# vote_part1                               0.672659
# vote_part2                               0.674920
# weather_nominal                          0.664001
# wifi_localization                        0.667990
# wilt                                     0.679252
# winequality_red_classification           0.663690
# winequality_white_classification         0.671648
# wine                                     0.668026
# yeast                                    0.666319
# zoo                                      0.673982

# %%
print('Average validation score of best models:',np.mean(df['Mean Score']))
# Out:
# Average validation score of best models: 0.6738129629901118

# %% [markdown]
# ### Best Model

# %%
best_model
# Out:
# 'EEG_Eye_State'

# %%
 # load the model from disk
# os.chdir('models')
filename = 'models\\best_model.sav'
best_model = pickle.load(open(filename, 'rb'))
best_model
# Out:
# Pipeline(steps=[('scaling', 'passthrough'), ('balance', None),
#                 ('classifier',
#                  HistGradientBoostingClassifier(learning_rate=0.01,
#                                                 max_depth=4))])

# %% [markdown]
# ### New Model x Wrapper

# %% [markdown]
# % of selected features (compared to complete dataset)

# %%
table3
# Out:
#                                   Dataset   Wrapper  New Model
# 0                                    iris  0.250000   0.250000
# 1                             labor_part1  0.375000   0.500000
# 2                             labor_part2  0.375000   0.250000
# 3                                   glass  0.666667   0.888889
# 4                           breast_cancer  0.333333   0.888889
# 5                          contact_lenses  0.500000   0.250000
# 6                          credit_g_part1  0.500000   0.300000
# 7                          credit_g_part2  0.400000   0.700000
# 8                                diabetes  0.875000   0.250000
# 9                       hypothyroid_part1  0.600000   0.900000
# 10                      hypothyroid_part2  0.600000   0.800000
# 11                      hypothyroid_part3  0.555556   0.444444
# 12                segment_challenge_part1  0.600000   0.500000
# 13                segment_challenge_part2  0.555556   1.000000
# 14                          soybean_part1  0.750000   0.916667
# 15                          soybean_part2  0.833333   1.000000
# 16                          soybean_part3  0.909091   0.818182
# 17                             vote_part1  0.750000   0.625000
# 18                             vote_part2  0.125000   0.625000
# 19                        weather_nominal  0.500000   0.500000
# 20                 abalone_classification  0.375000   1.000000
# 21                          balance_scale  1.000000   1.000000
# 22           data_banknote_authentication  0.750000   0.500000
# 23                 DishonestInternetUsers  0.750000   0.750000
# 24                                  ecoli  0.714286   0.857143
# 25                hayes_roth_trainAndtest  1.000000   0.500000
# 26                                hcvdat0  1.000000   0.916667
# 27                    mammographic_masses  1.000000   0.800000
# 28                          monks_1_train  0.166667   0.500000
# 29                          monks_2_train  0.666667   0.500000
# 30                                   wilt  0.600000   1.000000
# 31                          seeds_dataset  0.285714   0.714286
# 32                           Surveillance  0.142857   0.428571
# 33                                   wine  0.615385   0.692308
# 34         winequality_red_classification  0.727273   0.909091
# 35       winequality_white_classification  0.818182   0.909091
# 36                       ionosphere_part1  0.666667   0.750000
# 37                       ionosphere_part2  0.454545   0.545455
# 38                       ionosphere_part3  0.545455   0.909091
# 39                               avila_tr  0.900000   0.800000
# 40                               avila_ts  0.900000   1.000000
# 41                                    cmc  0.444444   0.888889
# 42                   sonar_all_data_part1  0.333333   0.666667
# 43                   sonar_all_data_part2  0.500000   0.500000
# 44                   sonar_all_data_part3  0.500000   0.416667
# 45                   sonar_all_data_part4  0.583333   0.416667
# 46                   sonar_all_data_part5  0.666667   0.416667
# 47                     accent_mfcc_data_1  0.916667   0.833333
# 48                          EEG_Eye_State  0.642857   0.714286
# 49                                magic04  0.400000   1.000000
# 50                      wifi_localization  0.857143   0.857143
# 51  ObesityDataSet_raw_and_data_sinthetic  0.625000   0.937500
# 52                                  yeast  0.875000   0.875000
# 53                                    zoo  0.375000   0.812500

# %%
print('Mean % of selected features by Wrapper :',np.mean(table3.Wrapper))
# Out:
# Mean % of selected features by Wrapper : 0.6083643722532612

# %%
print('Mean % of selected features by Proposed Model :',np.mean(table3['New Model']))
# Out:
# Mean % of selected features by Proposed Model : 0.6985942555386999

# %% [markdown]
# Mean Scores +- One Standard Deviation and Significant Statistical Difference

# %%
table2
# Out:
#                                   Dataset       Wrapper     New Model  \
# 0                                    iris   95.73+-4.76   94.87+-5.40
# 1                             labor_part1  89.70+-13.06  88.20+-14.00
# 2                             labor_part2  91.87+-11.55  82.20+-16.37
# 3                                   glass   64.83+-9.84  62.91+-10.66
# 4                           breast_cancer   75.75+-7.60   75.15+-8.13
# 5                          contact_lenses  83.67+-23.69  65.83+-32.09
# 6                          credit_g_part1   74.29+-4.30   72.01+-4.23
# 7                          credit_g_part2   72.46+-4.17   71.44+-4.36
# 8                                diabetes   76.51+-4.62   76.24+-4.93
# 9                       hypothyroid_part1   93.53+-1.15   93.51+-1.15
# 10                      hypothyroid_part2   93.83+-1.36   93.75+-1.35
# 11                      hypothyroid_part3   95.03+-1.03   95.03+-0.99
# 12                segment_challenge_part1   83.07+-2.90   76.36+-3.34
# 13                segment_challenge_part2   95.64+-1.76   95.51+-1.84
# 14                          soybean_part1   84.98+-3.66   84.67+-4.25
# 15                          soybean_part2   77.13+-4.40   75.49+-4.77
# 16                          soybean_part3   78.77+-4.38   71.52+-4.68
# 17                             vote_part1   90.55+-4.51   90.42+-4.44
# 18                             vote_part2   95.63+-2.72   95.61+-2.70
# 19                        weather_nominal  73.50+-39.66  73.50+-39.66
# 20                 abalone_classification   27.75+-1.97   26.68+-2.01
# 21                          balance_scale   93.66+-3.26   93.66+-3.26
# 22           data_banknote_authentication   98.63+-0.94   88.34+-2.79
# 23                 DishonestInternetUsers   99.88+-0.61   99.88+-0.61
# 24                                  ecoli   85.22+-5.99   86.65+-5.77
# 25                hayes_roth_trainAndtest   84.12+-7.98  61.75+-10.32
# 26                                hcvdat0   92.99+-3.42   92.29+-3.45
# 27                    mammographic_masses   82.35+-3.75   82.46+-3.67
# 28                          monks_1_train  73.38+-10.89  71.81+-11.88
# 29                          monks_2_train  59.71+-11.41  59.70+-11.62
# 30                                   wilt   96.30+-0.91   96.30+-0.83
# 31                          seeds_dataset   96.38+-4.16   94.00+-5.41
# 32                           Surveillance  77.00+-38.35  70.00+-41.23
# 33                                   wine   98.43+-3.37   96.75+-4.05
# 34         winequality_red_classification   59.65+-3.27   59.61+-3.31
# 35       winequality_white_classification   53.48+-1.92   53.00+-1.96
# 36                       ionosphere_part1   87.41+-5.40   85.44+-6.12
# 37                       ionosphere_part2   82.85+-5.73   82.94+-5.53
# 38                       ionosphere_part3   83.38+-6.19   82.96+-6.55
# 39                               avila_tr   56.15+-1.50   55.71+-1.53
# 40                               avila_ts   56.21+-1.40   56.01+-1.40
# 41                                    cmc   51.62+-3.40   51.32+-3.37
# 42                   sonar_all_data_part1   78.51+-8.90   73.85+-8.72
# 43                   sonar_all_data_part2   75.16+-9.17   73.72+-9.46
# 44                   sonar_all_data_part3   70.04+-9.94   68.32+-8.32
# 45                   sonar_all_data_part4   75.82+-8.82   74.05+-9.04
# 46                   sonar_all_data_part5   74.20+-7.61   72.50+-8.96
# 47                     accent_mfcc_data_1   73.57+-7.38   67.74+-7.55
# 48                          EEG_Eye_State   63.79+-1.39   59.72+-1.80
# 49                                magic04   79.20+-0.86   79.04+-0.81
# 50                      wifi_localization   98.31+-0.87   98.14+-0.90
# 51  ObesityDataSet_raw_and_data_sinthetic   97.00+-1.18   96.30+-1.30
# 52                                  yeast   59.04+-3.98   53.57+-3.80
# 53                                    zoo   97.15+-5.56   94.74+-6.21
#
#     Difference
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39        True
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47        True
# 48        True
# 49       False
# 50       False
# 51       False
# 52        True
# 53       False

# %%
print('Corrected t test statistic (Wrapper x New Model):')
print()
for i in ten_tencv_corrected_t_test:
    print(i,f'{ten_tencv_corrected_t_test[i][3]:.2f}')
    if ten_tencv_corrected_t_test[i][3]<0.05:
        exec('print("\tWrapper:",np.mean(scores_weka["{KEY}"]),"New:",np.mean(scores_new["{KEY}"]))'.format(KEY = i))
# Out:
# Corrected t test statistic (Wrapper x New Model):
#
# iris 0.72
# labor_part1 0.73
# labor_part2 0.07
# glass 0.37
# breast_cancer 0.49
# contact_lenses 0.05
# 	Wrapper: 83.66666666666669 New: 65.83333333333334
# credit_g_part1 0.03
# 	Wrapper: 74.29 New: 72.01
# credit_g_part2 0.21
# diabetes 0.78
# hypothyroid_part1 0.74
# hypothyroid_part2 0.30
# hypothyroid_part3 0.97
# segment_challenge_part1 0.00
# 	Wrapper: 83.07333333333334 New: 76.36
# segment_challenge_part2 0.63
# soybean_part1 0.76
# soybean_part2 0.17
# soybean_part3 0.00
# 	Wrapper: 78.76555839727195 New: 71.519820971867
# vote_part1 0.81
# vote_part2 0.77
# weather_nominal 1.00
# abalone_classification 0.08
# balance_scale 1.00
# data_banknote_authentication 0.00
# 	Wrapper: 98.62937691738074 New: 88.33973341796255
# DishonestInternetUsers 1.00
# ecoli 0.15
# hayes_roth_trainAndtest 0.00
# 	Wrapper: 84.125 New: 61.75
# hcvdat0 0.19
# mammographic_masses 0.66
# monks_1_train 0.67
# monks_2_train 1.00
# wilt 0.99
# seeds_dataset 0.13
# Surveillance 0.29
# wine 0.17
# winequality_red_classification 0.92
# winequality_white_classification 0.19
# ionosphere_part1 0.14
# ionosphere_part2 0.94
# ionosphere_part3 0.66
# avila_tr 0.02
# 	Wrapper: 56.15244487056568 New: 55.70949185043145
# avila_ts 0.16
# cmc 0.74
# sonar_all_data_part1 0.13
# sonar_all_data_part2 0.57
# sonar_all_data_part3 0.68
# sonar_all_data_part4 0.48
# sonar_all_data_part5 0.52
# accent_mfcc_data_1 0.00
# 	Wrapper: 73.57481060606061 New: 67.74431818181819
# EEG_Eye_State 0.00
# 	Wrapper: 63.78971962616823 New: 59.715620827770366
# magic04 0.38
# wifi_localization 0.28
# ObesityDataSet_raw_and_data_sinthetic 0.12
# yeast 0.00
# 	Wrapper: 59.04267186649736 New: 53.570741882822425
# zoo 0.22

# %%
print('Proportion of runs where results of a simple logistic regression applied over a subset defined by Proposed model versus  subset defined by Wrapper didn\'t have significative difference :')
print()
print(sum(table2['Difference']==False) / len(table2['Difference']))
# Out:
# Proportion of runs where results of a simple logistic regression applied over a subset defined by Proposed model versus  subset defined by Wrapper didn't have significative difference :
#
# 0.8148148148148148

# %% [markdown]
# ### New Model x Complete Dataset

# %%
table4
# Out:
#                                   Dataset      Complete     New Model  \
# 0                                    iris   96.27+-4.65   94.87+-5.40
# 1                             labor_part1  90.47+-12.11  88.20+-14.00
# 2                             labor_part2  86.10+-14.06  82.20+-16.37
# 3                                   glass  64.70+-10.17  62.91+-10.66
# 4                           breast_cancer   75.18+-7.87   75.15+-8.13
# 5                          contact_lenses  71.67+-26.72  65.83+-32.09
# 6                          credit_g_part1   72.96+-4.33   72.01+-4.23
# 7                          credit_g_part2   71.79+-4.31   71.44+-4.36
# 8                                diabetes   76.93+-4.51   76.24+-4.93
# 9                       hypothyroid_part1   93.51+-1.15   93.51+-1.15
# 10                      hypothyroid_part2   93.79+-1.35   93.75+-1.35
# 11                      hypothyroid_part3   95.03+-1.00   95.03+-0.99
# 12                segment_challenge_part1   79.24+-3.83   76.36+-3.34
# 13                segment_challenge_part2   95.51+-1.84   95.51+-1.84
# 14                          soybean_part1   84.67+-4.25   84.67+-4.25
# 15                          soybean_part2   75.49+-4.77   75.49+-4.77
# 16                          soybean_part3   78.18+-4.19   71.52+-4.68
# 17                             vote_part1   90.67+-4.25   90.42+-4.44
# 18                             vote_part2   95.63+-2.72   95.61+-2.70
# 19                        weather_nominal  50.50+-43.30  73.50+-39.66
# 20                 abalone_classification   26.68+-2.01   26.68+-2.01
# 21                          balance_scale   93.66+-3.26   93.66+-3.26
# 22           data_banknote_authentication   98.63+-0.94   88.34+-2.79
# 23                 DishonestInternetUsers   99.88+-0.61   99.88+-0.61
# 24                                  ecoli   86.65+-5.84   86.65+-5.77
# 25                hayes_roth_trainAndtest   84.12+-7.98  61.75+-10.32
# 26                                hcvdat0   92.99+-3.42   92.29+-3.45
# 27                    mammographic_masses   82.35+-3.75   82.46+-3.67
# 28                          monks_1_train  70.29+-11.56  71.81+-11.88
# 29                          monks_2_train  59.65+-11.90  59.70+-11.62
# 30                                   wilt   96.30+-0.83   96.30+-0.83
# 31                          seeds_dataset   95.33+-4.76   94.00+-5.41
# 32                           Surveillance  46.00+-44.54  70.00+-41.23
# 33                                   wine   98.04+-3.20   96.75+-4.05
# 34         winequality_red_classification   59.61+-3.31   59.61+-3.31
# 35       winequality_white_classification   53.43+-1.82   53.00+-1.96
# 36                       ionosphere_part1   85.84+-6.20   85.44+-6.12
# 37                       ionosphere_part2   81.94+-6.38   82.94+-5.53
# 38                       ionosphere_part3   82.84+-6.60   82.96+-6.55
# 39                               avila_tr   56.10+-1.50   55.71+-1.53
# 40                               avila_ts   56.01+-1.40   56.01+-1.40
# 41                                    cmc   50.62+-3.13   51.32+-3.37
# 42                   sonar_all_data_part1   76.79+-9.36   73.85+-8.72
# 43                   sonar_all_data_part2   72.75+-9.89   73.72+-9.46
# 44                   sonar_all_data_part3  70.14+-10.25   68.32+-8.32
# 45                   sonar_all_data_part4   74.69+-8.91   74.05+-9.04
# 46                   sonar_all_data_part5   73.62+-8.68   72.50+-8.96
# 47                     accent_mfcc_data_1   72.15+-7.32   67.74+-7.55
# 48                          EEG_Eye_State   60.85+-1.71   59.72+-1.80
# 49                                magic04   79.04+-0.81   79.04+-0.81
# 50                      wifi_localization   98.16+-0.96   98.14+-0.90
# 51  ObesityDataSet_raw_and_data_sinthetic   96.39+-1.27   96.30+-1.30
# 52                                  yeast   58.93+-3.87   53.57+-3.80
# 53                                    zoo   93.84+-8.08   94.74+-6.21
#
#     Difference
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32        True
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47        True
# 48       False
# 49       False
# 50       False
# 51       False
# 52        True
# 53       False

# %%
print('Corrected t test statistic (Complete Model x New Model):')
print()
for i in ten_tencv_corrected_t_test2:
    print(i,f'{ten_tencv_corrected_t_test2[i][3]:.2f}')
    if ten_tencv_corrected_t_test2[i][3]<0.05:
        exec('print("\tComplete:",np.mean(scores_complete["{KEY}"]),"New:",np.mean(scores_new["{KEY}"]))'.format(KEY = i))
# Out:
# Corrected t test statistic (Complete Model x New Model):
#
# iris 0.44
# labor_part1 0.44
# labor_part2 0.48
# glass 0.31
# breast_cancer 0.94
# contact_lenses 0.42
# credit_g_part1 0.36
# credit_g_part2 0.69
# diabetes 0.50
# hypothyroid_part1 1.00
# hypothyroid_part2 0.44
# hypothyroid_part3 0.98
# segment_challenge_part1 0.03
# 	Complete: 79.24 New: 76.36
# segment_challenge_part2 1.00
# soybean_part1 1.00
# soybean_part2 1.00
# soybean_part3 0.00
# 	Complete: 78.18307757885762 New: 71.519820971867
# vote_part1 0.79
# vote_part2 0.77
# weather_nominal 0.12
# abalone_classification 1.00
# balance_scale 1.00
# data_banknote_authentication 0.00
# 	Complete: 98.62937691738074 New: 88.33973341796255
# DishonestInternetUsers 1.00
# ecoli 1.00
# hayes_roth_trainAndtest 0.00
# 	Complete: 84.125 New: 61.75
# hcvdat0 0.19
# mammographic_masses 0.66
# monks_1_train 0.62
# monks_2_train 0.96
# wilt 1.00
# seeds_dataset 0.49
# Surveillance 0.04
# 	Complete: 46.0 New: 70.0
# wine 0.23
# winequality_red_classification 1.00
# winequality_white_classification 0.18
# ionosphere_part1 0.72
# ionosphere_part2 0.37
# ionosphere_part3 0.78
# avila_tr 0.06
# avila_ts 1.00
# cmc 0.44
# sonar_all_data_part1 0.31
# sonar_all_data_part2 0.66
# sonar_all_data_part3 0.50
# sonar_all_data_part4 0.80
# sonar_all_data_part5 0.63
# accent_mfcc_data_1 0.03
# 	Complete: 72.14962121212122 New: 67.74431818181819
# EEG_Eye_State 0.15
# magic04 1.00
# wifi_localization 0.84
# ObesityDataSet_raw_and_data_sinthetic 0.75
# yeast 0.00
# 	Complete: 58.93460910575005 New: 53.570741882822425
# zoo 0.66

# %%
print('Proportion of runs where results of a simple logistic regression applied over a subset defined by Proposed model versus the complete dataset didn\'t have significative difference :')
print()
print(sum(table4['Difference']==False) / len(table4['Difference']))
# Out:
# Proportion of runs where results of a simple logistic regression applied over a subset defined by Proposed model versus the complete dataset didn't have significative difference :
#
# 0.8703703703703703
